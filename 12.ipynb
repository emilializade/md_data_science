# %%
import pandas as pd

melb_df = pd.read_csv('data/melb_data_ps.csv')
melb_df.head()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...    1     202.0         126.0       1970
# 1  4/02/2016       2.5  ...    0     156.0          79.0       1900
# 2  4/03/2017       2.5  ...    0     134.0         150.0       1900
# 3  4/03/2017       2.5  ...    1      94.0         126.0       1970
# 4  4/06/2016       2.5  ...    2     120.0         142.0       2014
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# ...

# %%
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  int64
#  12  Bathroom       13580 non-null  int64
#  13  Car            13580 non-null  int64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  int64
# ...

# %%
melb_df.sort_values(by='Price').head(10)
# Out:
#        index          Suburb             Address  Rooms Type     Price Method  \
# 2652    2652       Footscray    202/51 Gordon St      1    u   85000.0     PI
# 1805    1805       Caulfield          30 Pyne St      4    h  131000.0     PI
# 7303    7303          Albion       8/6 Ridley St      1    u  145000.0     PI
# 1927    1927          Coburg     171 Moreland Rd      4    h  145000.0     PI
# 7940    7940        Hawthorn       17/17 Park St      1    u  160000.0     VB
# 12666  12666       Brunswick       4/831 Park St      1    u  170000.0     VB
# 8811    8811       Footscray    10/30 Pickett St      1    u  170000.0     PI
# 8504    8504  West Footscray     8/132 Rupert St      1    u  185000.0     PI
# 7293    7293          Albion  10/117 Anderson Rd      1    u  185000.0      S
# 7305    7305          Albion      5/25 Ridley St      2    u  190000.0     SP
#
#              SellerG        Date  Distance  ...  Car  Landsize  BuildingArea  \
# ...

# %%
melb_df.sort_values(by='Date', ascending=False)
# Out:
#        index      Suburb              Address  Rooms Type      Price Method  \
# 12497  12497     Fitzroy          101 Kerr St      3    h  1750000.0     VB
# 12555  12555     Mentone        14A Teague Av      3    t   875000.0      S
# 12543  12543    Kew East            29 Elm Gr      3    h  1655000.0     SA
# 12542  12542    Kew East        11 Coleman Av      4    h  2000000.0     VB
# 12541  12541    Kew East       38 Bennett Pde      3    h  1700000.0      S
# ...      ...         ...                  ...    ...  ...        ...    ...
# 8957    8957     Sunbury     11 Bannermann St      4    h   580000.0      S
# 8956    8956  Strathmore        2/30 Bulla Rd      2    h   646000.0      S
# 8830    8830    Hawthorn          7/28 Elm St      1    u   395000.0      S
# 8831    8831    Hawthorn  1/514 Glenferrie Rd      3    u  1000000.0      S
# 8793    8793     Donvale        1 Bernarra Ct      7    h  2705000.0      S
#
# ...

# %%
melb_df.sort_values(by=['Distance', 'Price']).loc[::10, ['Distance', 'Price']]
# Out:
#        Distance      Price
# 11428       0.0   387000.0
# 10512       0.7   600000.0
# 5727        1.2   485000.0
# 8671        1.2   595000.0
# 5736        1.2   740000.0
# ...         ...        ...
# 12011      38.0   680000.0
# 10673      38.0   810000.0
# 13429      38.0  1155000.0
# 11102      41.0   650000.0
# 12728      45.9   650000.0
#
# [1358 rows x 2 columns]

# %%
# Загрузите именно этот файл, чтобы цифры совпали с тестом
basic_df = pd.read_csv('data/melb_data.csv') 
basic_df['Date'] = pd.to_datetime(basic_df['Date'], dayfirst=True)
print(basic_df['Date'].dt.quarter.value_counts())

# %%
import pandas as pd

# Загружаем файл
melb_df = pd.read_csv('data/melb_data_ps.csv')

# Важно: указываем dayfirst=True, чтобы формат был ДД/ММ/ГГГГ
melb_df['Date'] = pd.to_datetime(melb_df['Date'], dayfirst=True)

# Считаем кварталы
res = melb_df['Date'].dt.quarter.value_counts()
print(res)
# Out:
# Date
# 3    5377
# 2    4808
# 4    2272
# 1    1123
# Name: count, dtype: int64

# %%
melb_df.groupby(by='Type').mean(numeric_only=True)
# Out:
#             index     Rooms         Price   Distance     Postcode   Bedroom  \
# Type
# h     7075.985924  3.260874  1.242665e+06  10.979479  3104.080643  3.229336
# t     6269.107720  2.837522  9.337351e+05   9.851346  3100.777379  2.814183
# u     6084.399403  1.963871  6.051275e+05   7.607391  3110.797481  1.966523
#
#       Bathroom       Car    Landsize  BuildingArea    YearBuilt  Lattitude  \
# Type
# h     1.613822  1.772674  617.181924    152.162553  1960.889089 -37.803795
# t     1.809695  1.555655  279.606822    134.649710  1989.828546 -37.815782
# u     1.183295  1.128936  477.314219    102.235863  1976.756381 -37.823710
#
#       Longtitude  Propertycount
# Type
# h     144.994700    7259.025505
# t     144.996489    7094.459605
# u     144.996363    8199.280080

# %%
melb_df.groupby('Type')['Price'].mean()
# Out:
# Type
# h    1.242665e+06
# t    9.337351e+05
# u    6.051275e+05
# Name: Price, dtype: float64

# %%
melb_df.groupby('Regionname')['Distance'].min().sort_values(ascending=False)
# Out:
# Regionname
# Western Victoria              29.8
# Eastern Victoria              25.2
# Northern Victoria             21.8
# South-Eastern Metropolitan    14.7
# Eastern Metropolitan           7.8
# Western Metropolitan           4.3
# Southern Metropolitan          0.7
# Northern Metropolitan          0.0
# Name: Distance, dtype: float64

# %%
melb_df.groupby ('MonthSale')['Price'].agg(
    ['count', 'mean', 'max']
).sort_values(by='count', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 melb_df.groupby ('MonthSale')['Price'].agg(
#       2     ['count', 'mean', 'max']
#       3 ).sort_values(by='count', ascending=False)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:9210, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9207 if level is None and by is None:
#    9208     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9210 return DataFrameGroupBy(
#    9211     obj=self,
#    9212     keys=by,
#    9213     axis=axis,
#    9214     level=level,
#    9215     as_index=as_index,
#    9216     sort=sort,
#    9217     group_keys=group_keys,
#    9218     observed=observed,
#    9219     dropna=dropna,
#    9220 )
#
# ...

# %%
melb_df.groupby('Regionname')['SellerG'].agg(
    		['nunique', set]
)
# Out:
#                             nunique  \
# Regionname
# Eastern Metropolitan             70
# Eastern Victoria                 18
# Northern Metropolitan           112
# Northern Victoria                16
# South-Eastern Metropolitan       52
# Southern Metropolitan           131
# Western Metropolitan             92
# Western Victoria                  9
#
#                                                                           set
# Regionname
# Eastern Metropolitan        {Buckingham, Woodards, Lindellas, Assisi, Noel...
# Eastern Victoria            {Eview, Ray, Harcourts, Morrison, McGrath, Pea...
# Northern Metropolitan       {Nick, Woodards, Walshe, Pagan, Iconek, buyMyp...
# Northern Victoria           {Buckingham, LITTLE, Reliance, hockingstuart, ...
# South-Eastern Metropolitan  {Eview, Woodards, Veitch, U, Noel, Aquire, Bar...
# Southern Metropolitan       {Nick, Woodards, Assisi, Walshe, buyMyplace, M...
# ...

# %%
melb_df.groupby('Rooms')[['Price', 'BuildingArea']].median()
# Out:
#            Price  BuildingArea
# Rooms
# 1       385000.0         107.0
# 2       690000.0         126.0
# 3       950000.0         126.0
# 4      1285000.0         142.0
# 5      1660000.0         176.0
# 6      1800000.0         126.0
# 7      1496000.0         216.5
# 8      1515000.0         126.0
# 10      900000.0         126.0

# %%
melb_df.groupby(['Rooms', 'Type'])['Price'].mean()
# Out:
# Rooms  Type
# 1      h       8.668655e+05
#        t       5.927045e+05
#        u       3.899289e+05
# 2      h       1.017238e+06
#        t       7.101585e+05
#        u       6.104905e+05
# 3      h       1.109233e+06
#        t       9.847087e+05
#        u       8.505963e+05
# 4      h       1.462283e+06
#        t       1.217092e+06
#        u       1.037476e+06
# 5      h       1.877327e+06
#        t       1.035000e+06
# 6      h       1.869508e+06
#        u       5.200000e+05
# 7      h       1.920700e+06
# 8      h       1.510286e+06
#        u       2.250000e+06
# 10     h       9.000000e+05
# Name: Price, dtype: float64

# %%
melb_df.groupby(['Rooms', 'Type'])['Price'].mean().unstack()
# Out:
# Type              h             t             u
# Rooms
# 1      8.668655e+05  5.927045e+05  3.899289e+05
# 2      1.017238e+06  7.101585e+05  6.104905e+05
# 3      1.109233e+06  9.847087e+05  8.505963e+05
# 4      1.462283e+06  1.217092e+06  1.037476e+06
# 5      1.877327e+06  1.035000e+06           NaN
# 6      1.869508e+06           NaN  5.200000e+05
# 7      1.920700e+06           NaN           NaN
# 8      1.510286e+06           NaN  2.250000e+06
# 10     9.000000e+05           NaN           NaN

# %%
melb_df.pivot_table(
    values='Price',
    index='Rooms',
    columns='Type',
    fill_value=0
).round()
# Out:
# Type           h          t          u
# Rooms
# 1       866866.0   592705.0   389929.0
# 2      1017238.0   710158.0   610491.0
# 3      1109233.0   984709.0   850596.0
# 4      1462283.0  1217092.0  1037476.0
# 5      1877327.0  1035000.0        0.0
# 6      1869508.0        0.0   520000.0
# 7      1920700.0        0.0        0.0
# 8      1510286.0        0.0  2250000.0
# 10      900000.0        0.0        0.0

# %%
melb_df.pivot_table(
    values='Price',
    index='Regionname',
    columns='Weekend',
    aggfunc='count'
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 melb_df.pivot_table(
#       2     values='Price',
#       3     index='Regionname',
#       4     columns='Weekend',
#       5     aggfunc='count'
#       6 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:9536, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9519 @Substitution("")
#    9520 @Appender(_shared_docs["pivot_table"])
#    9521 def pivot_table(
#    (...)
#    9532     sort: bool = True,
#    9533 ) -> DataFrame:
#    9534     from pandas.core.reshape.pivot import pivot_table
# -> 9536     return pivot_table(
#    9537         self,
#    9538         values=values,
#    9539         index=index,
#    9540         columns=columns,
#    9541         aggfunc=aggfunc,
# ...

# %%
melb_df.pivot_table(
    values='Landsize',
    index='Regionname',
    columns='Type',
    aggfunc=['median', 'mean'],
    fill_value=0
)
# Out:
#                            median                       mean              \
# Type                            h      t      u            h           t
# Regionname
# Eastern Metropolitan        674.0  233.5  203.0   717.422847  269.440678
# Eastern Victoria            843.0    0.0  230.0  3108.960000    0.000000
# Northern Metropolitan       459.5  134.0    0.0   619.249092  317.325733
# Northern Victoria           724.0    0.0    0.0  3355.463415    0.000000
# South-Eastern Metropolitan  630.5  240.0  199.0   664.306701  212.160000
# Southern Metropolitan       586.0  246.0    0.0   569.643881  278.858824
# Western Metropolitan        531.0  198.0   62.0   507.883406  244.560669
# Western Victoria            599.5    0.0    0.0   655.500000    0.000000
#
#
# Type                                 u
# Regionname
# Eastern Metropolitan        330.444444
# Eastern Victoria            295.333333
# Northern Metropolitan       495.026538
# Northern Victoria             0.000000
# ...

# %%
melb_df.pivot_table(
    values='Price',
    index=['Method','Type'],
    columns='Regionname',
    aggfunc='median',
    fill_value=0
)
# Out:
# Regionname   Eastern Metropolitan  Eastern Victoria  Northern Metropolitan  \
# Method Type
# PI     h                1244000.0          780000.0               900000.0
#        t                 760000.0               0.0               632500.0
#        u                 650000.0               0.0               410000.0
# S      h                1127000.0          675000.0               920000.0
#        t                 828000.0               0.0               750000.0
#        u                 645750.0          492000.0               525500.0
# SA     h                 932500.0          950000.0               817500.0
#        t                 807500.0               0.0               425000.0
#        u                      0.0               0.0               616000.0
# SP     h                1050000.0          672500.0               900000.0
#        t                 910000.0               0.0               690000.0
# ...

# %%
pivot = melb_df.pivot_table(
    values='Landsize',
    index='Regionname',
    columns='Type',
    aggfunc=['median', 'mean'],
    fill_value=0
)

# %%
pivot.columns
# Out:
# MultiIndex([('median', 'h'),
#             ('median', 't'),
#             ('median', 'u'),
#             (  'mean', 'h'),
#             (  'mean', 't'),
#             (  'mean', 'u')],
#            names=[None, 'Type'])

# %%
display(pivot['mean']['u'])
# Out:
# Regionname
# Eastern Metropolitan          330.444444
# Eastern Victoria              295.333333
# Northern Metropolitan         495.026538
# Northern Victoria               0.000000
# South-Eastern Metropolitan    357.864865
# Southern Metropolitan         466.380245
# Western Metropolitan          557.637232
# Western Victoria                0.000000
# Name: u, dtype: float64

# %%
mask = pivot['mean']['h'] < pivot['median']['h']
filtered_pivot = pivot[mask]
display(filtered_pivot)
# Out:
#                       median                     mean
# Type                       h      t     u           h           t           u
# Regionname
# Southern Metropolitan  586.0  246.0   0.0  569.643881  278.858824  466.380245
# Western Metropolitan   531.0  198.0  62.0  507.883406  244.560669  557.637232

# %%
print(list(filtered_pivot.index))
# ['Southern Metropolitan', 'Western Metropolitan']
# Out:
# ['Southern Metropolitan', 'Western Metropolitan']

# %%
import numpy as np
mser = pd.Series(
    np.random.rand(8),
	index=[['white','white','white','blue','blue','red','red','red'], 
           ['up','down','right','up','down','up','down','left']])
display(mser)
# Out:
# white  up       0.003999
#        down     0.558890
#        right    0.941205
# blue   up       0.659962
#        down     0.580206
# red    up       0.960867
#        down     0.230802
#        left     0.069761
# dtype: float64

# %%
import pandas as pd

ratings1 = pd.read_csv('data/ratings1.csv')
ratings2 = pd.read_csv('data/ratings2.csv')
dates = pd.read_csv('data/dates.csv')
movies = pd.read_csv('data/movies.csv')

# %%
import pandas as pd

# Склеиваем таблицы с рейтингами
ratings = pd.concat([ratings1, ratings2], ignore_index=True)

# Добавляем столбец с датой
ratings = pd.concat([ratings, dates], axis=1)

# Присоединяем информацию о фильмах
movies_ratings = ratings.merge(movies, on='movieId', how='left')

# Выводим первые строки итоговой таблицы
movies_ratings.head()
# Out:
#    userId  movieId  rating                 date                        title  \
# 0       1        1     4.0  2000-07-30 18:45:03             Toy Story (1995)
# 1       1        3     4.0  2000-07-30 18:20:47      Grumpier Old Men (1995)
# 2       1        6     4.0  2000-07-30 18:37:04                  Heat (1995)
# 3       1       47     5.0  2000-07-30 19:03:35  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0  2000-07-30 18:48:51   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller

# %%
movies['title'].nunique()
# Out:
# 9737

# %%
ratings1['userId'].nunique()
# Out:
# 274

# %%
dates['date'] = pd.to_datetime(dates['date'])

dates['year'] = dates['date'].dt.year

dates['year'].value_counts().idxmax()
# Out:
# np.int32(2000)

# %%
ratings = pd.concat([ratings1, ratings2])
display(ratings)
# Out:
#        userId  movieId  rating
# 0           1        1     4.0
# 1           1        3     4.0
# 2           1        6     4.0
# 3           1       47     5.0
# 4           1       50     5.0
# ...       ...      ...     ...
# 60831     610   166534     4.0
# 60832     610   168248     5.0
# 60833     610   168250     5.0
# 60834     610   168252     5.0
# 60835     610   170875     3.0
#
# [100837 rows x 3 columns]

# %%
ratings = pd.concat(
    [ratings1, ratings2],
    ignore_index=True
)
display(ratings)
# Out:
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100832     610   166534     4.0
# 100833     610   168248     5.0
# 100834     610   168250     5.0
# 100835     610   168252     5.0
# 100836     610   170875     3.0
#
# [100837 rows x 3 columns]

# %%
print('Число строк в таблице ratings: ', ratings.shape[0])
print('Число строк в таблице dates: ', dates.shape[0])
print(ratings.shape[0] == dates.shape[0])
# Out:
# Число строк в таблице ratings:  100837
# Число строк в таблице dates:  100836
# False

# %%
display(ratings1.tail(1))
display(ratings2.head(1))
# Out:
#        userId  movieId  rating
# 40000     274     5621     2.0
#    userId  movieId  rating
# 0     274     5621     2.0

# %%
ratings = ratings.drop_duplicates(ignore_index=True)
print('Число строк в таблице ratings: ', ratings.shape[0])
# Out:
# Число строк в таблице ratings:  100836

# %%
ratings_dates = pd.concat([ratings, dates], axis=1)
display(ratings_dates.tail(7))
# Out:
#         userId  movieId  rating                date  year
# 100829     610   164179     5.0 2017-05-03 21:07:11  2017
# 100830     610   166528     4.0 2017-05-04 06:29:25  2017
# 100831     610   166534     4.0 2017-05-03 21:53:22  2017
# 100832     610   168248     5.0 2017-05-03 22:21:31  2017
# 100833     610   168250     5.0 2017-05-08 19:50:47  2017
# 100834     610   168252     5.0 2017-05-03 21:19:12  2017
# 100835     610   170875     3.0 2017-05-03 21:20:15  2017

# %%
joined_false = ratings_dates.join(
    movies,
    rsuffix='_right',
    how='left'
)
display(joined_false)
# Out:
#         userId  movieId  rating                date  year  movieId_right  \
# 0            1        1     4.0 2000-07-30 18:45:03  2000            1.0
# 1            1        3     4.0 2000-07-30 18:20:47  2000            2.0
# 2            1        6     4.0 2000-07-30 18:37:04  2000            3.0
# 3            1       47     5.0 2000-07-30 19:03:35  2000            4.0
# 4            1       50     5.0 2000-07-30 18:48:51  2000            5.0
# ...        ...      ...     ...                 ...   ...            ...
# 100831     610   166534     4.0 2017-05-03 21:53:22  2017            NaN
# 100832     610   168248     5.0 2017-05-03 22:21:31  2017            NaN
# 100833     610   168250     5.0 2017-05-08 19:50:47  2017            NaN
# 100834     610   168252     5.0 2017-05-03 21:19:12  2017            NaN
# 100835     610   170875     3.0 2017-05-03 21:20:15  2017            NaN
#
#                                      title  \
# 0                         Toy Story (1995)
# ...

# %%
joined = ratings_dates.join(
    movies.set_index('movieId'),
    on='movieId',
    how='left'
)
display(joined.head())
# Out:
#    userId  movieId  rating                date  year  \
# 0       1        1     4.0 2000-07-30 18:45:03  2000
# 1       1        3     4.0 2000-07-30 18:20:47  2000
# 2       1        6     4.0 2000-07-30 18:37:04  2000
# 3       1       47     5.0 2000-07-30 19:03:35  2000
# 4       1       50     5.0 2000-07-30 18:48:51  2000
#
#                          title                                       genres
# 0             Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1      Grumpier Old Men (1995)                               Comedy|Romance
# 2                  Heat (1995)                        Action|Crime|Thriller
# 3  Seven (a.k.a. Se7en) (1995)                             Mystery|Thriller
# 4   Usual Suspects, The (1995)                       Crime|Mystery|Thriller

# %%
merged = ratings_dates.merge(
    movies,
    on='movieId',
    how='left'
)
display(merged.head())
# Out:
#    userId  movieId  rating                date  year  \
# 0       1        1     4.0 2000-07-30 18:45:03  2000
# 1       1        3     4.0 2000-07-30 18:20:47  2000
# 2       1        6     4.0 2000-07-30 18:37:04  2000
# 3       1       47     5.0 2000-07-30 19:03:35  2000
# 4       1       50     5.0 2000-07-30 18:48:51  2000
#
#                          title                                       genres
# 0             Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1      Grumpier Old Men (1995)                               Comedy|Romance
# 2                  Heat (1995)                        Action|Crime|Thriller
# 3  Seven (a.k.a. Se7en) (1995)                             Mystery|Thriller
# 4   Usual Suspects, The (1995)                       Crime|Mystery|Thriller

# %%
print('Число строк в таблице ratings_dates: ', ratings_dates.shape[0])
print('Число строк в таблице merged: ', merged.shape[0])
print(ratings_dates.shape[0] == merged.shape[0])
# Out:
# Число строк в таблице ratings_dates:  100836
# Число строк в таблице merged:  100836
# True

# %%
merged2 = ratings_dates.merge(
    movies,
    on='movieId',
    how='outer'
)
print('Число строк в таблице merged2: ', merged2.shape[0])
display(merged2.tail())
# Out:
# Число строк в таблице merged2:  100854
#         userId  movieId  rating                date    year  \
# 100849   184.0   193581     4.0 2018-09-16 14:44:42  2018.0
# 100850   184.0   193583     3.5 2018-09-16 14:52:25  2018.0
# 100851   184.0   193585     3.5 2018-09-16 14:56:45  2018.0
# 100852   184.0   193587     3.5 2018-09-16 15:00:21  2018.0
# 100853   331.0   193609     4.0 2018-09-17 04:13:26  2018.0
#
#                                             title  \
# 100849  Black Butler: Book of the Atlantic (2017)
# 100850               No Game No Life: Zero (2017)
# 100851                               Flint (2017)
# 100852        Bungo Stray Dogs: Dead Apple (2018)
# 100853        Andrew Dice Clay: Dice Rules (1991)
#
#                                  genres
# 100849  Action|Animation|Comedy|Fantasy
# 100850         Animation|Comedy|Fantasy
# 100851                            Drama
# 100852                 Action|Animation
# 100853                           Comedy

# %%
merge_ratings = ratings1.merge(ratings2, how='outer')
print('Число строк в таблице merge_ratings: ', merge_ratings.shape[0])
display(merge_ratings)
# Out:
# Число строк в таблице merge_ratings:  100836
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100831     610   166534     4.0
# 100832     610   168248     5.0
# 100833     610   168250     5.0
# 100834     610   168252     5.0
# 100835     610   170875     3.0
#
# [100836 rows x 3 columns]

# %%
data_1 = pd.DataFrame({'Value': [100, 45, 80],
                       'Group': [1, 4, 5]},
                      index = ['I0', 'I1', 'I2']
                     )

# %%
data_2 = pd.DataFrame({'Company': ['Google', 'Amazon', 'Facebook'],
                       'Add': ['S0', 'S1', 'S7']},
                      index = ['I0', 'I1', 'I3']
                     )

# %%
data_1.join(data_2, how='inner')
# Out:
#     Value  Group Company Add
# I0    100      1  Google  S0
# I1     45      4  Amazon  S1

# %%
a = pd.DataFrame({'A': ['a', 'b', 'c'], 'B': [103, 214, 124], 'C': [1, 4, 2]})

# %%
b = pd.DataFrame({'V': ['d', 'b', 'c'], 'U': [1393.7, 9382.2, 1904.5], 'C': [1, 3, 2]})

# %%
a.merge(b, how='right', on='C')
# Out:
#      A      B  C  V       U
# 0    a  103.0  1  d  1393.7
# 1  NaN    NaN  3  b  9382.2
# 2    c  124.0  2  c  1904.5

# %%
import re 
def get_year_release(arg):
    #находим все слова по шаблону "(DDDD)"
    candidates = re.findall(r'\(\d{4}\)', arg) 
    # проверяем число вхождений
    if len(candidates) > 0:
        #если число вхождений больше 0,
	#очищаем строку от знаков "(" и ")"
        year = candidates[0].replace('(', '')
        year = year.replace(')', '')
        return int(year)
    else:
        #если год не указан, возвращаем None
        return None

# %%
movies['year_release'] = movies['title'].str.extract(r'\((\d{4})\)')
movies['year_release'].isna().sum()
# Out:
# np.int64(13)

# %%
movies['year_release'] = movies['title'].str.extract(r'\((\d{4})\)$')

ratings_movies = ratings.merge(movies, on='movieId', how='left')

movie_1999 = ratings_movies[ratings_movies['year_release'] == '1999']

movie_1999.groupby('title')['rating'].mean().sort_values().index[0]
# Out:
# 'Bloodsport: The Dark Kumite (1999)'

# %%
movies['year_release'] = movies['title'].str.extract(r'\((\d{4})\)$')

ratings_movies = ratings.merge(movies, on='movieId', how='left')

movies_2010 = ratings_movies[ratings_movies['year_release'] == '2010']

movies_2010.groupby('genres')['rating'].mean().sort_values().index[0]
# Out:
# 'Action|Sci-Fi'

# %%
ratings_movies = ratings.merge(movies, on='movieId', how='left')

ratings_movies.groupby('userId')['genres'].nunique().sort_values(ascending=False).index[0]
# Out:
# np.int64(599)

# %%
users_stat = ratings.groupby('userId')['rating'].agg(['count', 'mean'])

users_stat.sort_values(by=['count', 'mean'], ascending=[True, False]).index[0]
# Out:
# np.int64(53)

# %%
movies['year_release'] = movies['title'].str.extract(r'\((\d{4})\)')
ratings_movies = ratings.merge(movies, on='movieId', how='left')
movies_2018 = ratings_movies[ratings_movies['year_release'] == '2018']
genres_start = movies_2018.groupby('genres')['rating'].agg(['mean', 'count'])
genres_start = genres_start[genres_start['count'] >= 10]
genres_start.sort_values(by='mean', ascending=False).index[0]
# Out:
# 'Action|Adventure|Sci-Fi'

# %%
ratings_movies['date'] = pd.to_datetime(ratings_movies['date'])

ratings_movies['year_rating'] = ratings_movies['date'].dt.year

pivot = ratings_movies.pivot_table(
    values='rating',
    index='genres',
    columns='year_rating',
    aggfunc='mean'
)

pivot
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 1
# ...

# %%
ratings = pd.concat([ratings1, ratings2], ignore_index=True)

ratings = pd.concat([ratings, dates], axis=1)

# %%
ratings_movies = ratings.merge(movies, on='movieId', how='left')

# %%
ratings_movies['date'] = pd.to_datetime(ratings_movies['date'])

ratings_movies['year_rating'] = ratings_movies['date'].dt.year

pivot = ratings_movies.pivot_table(
    values='rating',
    index='genres',
    columns='year_rating',
    aggfunc='mean'
)

pivot
# Out:
# year_rating                            1996.0    1997.0  1998.0  1999.0  \
# genres
# (no genres listed)                        NaN       NaN     NaN     NaN
# Action                               2.720000  3.500000     NaN     NaN
# Action|Adventure                     3.500000  4.050000    4.75     4.0
# Action|Adventure|Animation           3.000000       NaN     NaN     NaN
# Action|Adventure|Animation|Children       NaN       NaN     NaN     NaN
# ...                                       ...       ...     ...     ...
# Sci-Fi|Thriller                      3.000000  3.400000     NaN     4.0
# Sci-Fi|Thriller|IMAX                      NaN       NaN     NaN     NaN
# Thriller                             3.846154  3.857143    3.80     3.7
# War                                       NaN       NaN     NaN     4.5
# Western                              3.166667  3.000000     NaN     4.0
#
# year_rating                            2000.0    2001.0    2002.0    2003.0  \
# genres
# ...

# %%
orders_products = orders.merge(
    products,
    on='product_id',
    how='left'
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 orders_products = orders.merge(
#       2     products,
#       3     on='product_id',
#       4     how='left'
#       5 )
#
# NameError: name 'orders' is not defined

# %%
import pandas as pd

orders = pd.read_csv('orders.csv')
products = pd.read_csv('products.csv')

orders_products = orders.merge(
    products,
    on='ID товара',
    how='left'
)

orders_products
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[63], line 3
#       1 import pandas as pd
# ----> 3 orders = pd.read_csv('orders.csv')
#       4 products = pd.read_csv('products.csv')
#       6 orders_products = orders.merge(
#       7     products,
#       8     on='ID товара',
#       9     how='left'
#      10 )
#
# ...

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# /Users/emiliaalieva/IDE/Skillfactory/PY_10_Введение в Pandas
# ['введение.ipynb', '12.ipynb', '.venv', 'data']

# %%
orders = pd.read_csv('data/orders.csv')
products = pd.read_csv('data/products.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[58], line 2
#       1 orders = pd.read_csv('data/orders.csv')
# ----> 2 products = pd.read_csv('data/products.csv')
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
products = pd.read_csv('data/products.csv', sep=';')

# %%
orders = pd.read_csv('data/orders.csv', sep=';')

# %%
orders_products = orders.merge(
    products,
    on='ID товара',
    how='left'
)

orders_products
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/8q/042m9s296pq9gl81c0t5433c0000gn/T/ipykernel_8975/3974316009.py in ?()
# ----> 1 orders_products = orders.merge(
#       2     products,
#       3     on='ID товара',
#       4     how='left'
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10855         validate: MergeValidate | None = None,
#   10856     ) -> DataFrame:
#   10857         from pandas.core.reshape.merge import merge
#   10858
# > 10859         return merge(
#   10860             self,
#   10861             right,
#   10862             how=how,
#
# ...

# %%
orders_products = orders.merge(
    products,
    on='Product_ID',
    how='left'
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/8q/042m9s296pq9gl81c0t5433c0000gn/T/ipykernel_8975/3863437543.py in ?()
# ----> 1 orders_products = orders.merge(
#       2     products,
#       3     on='Product_ID',
#       4     how='left'
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10855         validate: MergeValidate | None = None,
#   10856     ) -> DataFrame:
#   10857         from pandas.core.reshape.merge import merge
#   10858
# > 10859         return merge(
#   10860             self,
#   10861             right,
#   10862             how=how,
#
# ...

# %%
paid_orders = orders_products[orders_products['Оплачен'] == 'Да']

paid_orders['profit'] = (
    paid_orders['Количество'] * paid_orders['Price']
)

paid_orders.groupby('ID Покупателя')['profit'] \
    .sum() \
    .sort_values(ascending=False) \
    .index[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 paid_orders = orders_products[orders_products['Оплачен'] == 'Да']
#       3 paid_orders['profit'] = (
#       4     paid_orders['Количество'] * paid_orders['Price']
#       5 )
#       7 paid_orders.groupby('ID Покупателя')['profit'] \
#       8     .sum() \
#       9     .sort_values(ascending=False) \
#      10     .index[0]
#
# NameError: name 'orders_products' is not defined
